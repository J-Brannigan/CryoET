# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import copick
import zarr
import os
import json

# %%
# Load the configuration
copickRoot = copick.from_file('../../copick_config.json')
runs = copickRoot.runs
run = copickRoot.get_run(runs[0].name)

voxel_spacing = run.get_voxel_spacing(10.000)

# Access the specific tomogram
tomogram = voxel_spacing.get_tomogram("denoised")

# Access the Zarr data
zarr_store = tomogram.zarr()
zarr_group = zarr.open(zarr_store)
# Load the tomogram data
tomogram_vals = zarr_group['0']  # Adjust the key if needed
num_slices = tomogram_vals.shape[0]  # Number of slices in the z-dimension

# %%
# Load the tomogram data
tomogram_vals = zarr_group['0']  # Adjust the key if needed
num_slices = tomogram_vals.shape[0]  # Number of slices in the z-dimension

# Path to the Picks folder
picks_folder = '/Users/jake.brannigan/Documents/Kaggle/CryoET/Data/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks'

def load_picks(picks_folder, voxel_spacing):
    picks = {}
    for json_file in os.listdir(picks_folder):
        if json_file.endswith('.json'):
            json_path = os.path.join(picks_folder, json_file)
            with open(json_path, 'r') as file:
                pick_data = json.load(file)
            picks[json_file[:-5]] = np.array([
                [point['location']['x'] / voxel_spacing.voxel_size,
                 point['location']['y'] / voxel_spacing.voxel_size,
                 point['location']['z'] / voxel_spacing.voxel_size]
                for point in pick_data['points']
            ])
    return picks

def map_picks_to_slices(picks, num_slices, copick_config):
    """
    Maps particle picks to slices based on their z-coordinates and particle radius.

    Args:
        picks (dict): Dictionary where keys are particle names and values are their 3D locations (numpy arrays).
        num_slices (int): Number of slices to consider along the z-axis.
        copick_config: The copick configuration object containing `pickable_objects`.

    Returns:
        dict: Dictionary mapping slice indices to filtered particle locations.
    """
    # Create a mapping of particle names to their radii from the copick configuration
    particle_radii = {
    obj.name: (obj.radius / 10 if obj.radius is not None else obj.radius)
    for obj in copick_config.pickable_objects
    }

    # Initialize a dictionary for storing particle locations for each slice
    plot_particles = {}
    for slice_idx in range(num_slices):
        plot_particles[slice_idx] = {
            particle: locations[np.abs(locations[:, 2] - slice_idx) < particle_radii[particle]].tolist()
            for particle, locations in picks.items()
        }

    return plot_particles

# Usage
picks = load_picks(picks_folder, voxel_spacing)

# %%
# Example: Extract patches around particles for training
def extract_patches(data, picks, patch_size=16):
    """
    Extracts cubic patches around particle locations.

    Args:
        data (numpy array): 3D tomogram volume.
        picks (dict): Dictionary with particle types as keys and 3D coordinates as values.
        patch_size (int): Size of the cubic patch.

    Returns:
        patches (numpy array): Extracted patches.
        labels (list): Corresponding labels for the patches.
    """
    patches = []
    labels = []
    half_size = patch_size // 2

    for particle, locations in picks.items():
        for loc in locations:
            x, y, z = map(int, loc)
            # Ensure patch is within bounds
            if (x - half_size >= 0 and x + half_size < data.shape[2] and
                y - half_size >= 0 and y + half_size < data.shape[1] and
                z - half_size >= 0 and z + half_size < data.shape[0]):
                patch = data[z-half_size:z+half_size,
                             y-half_size:y+half_size,
                             x-half_size:x+half_size]
                patches.append(patch)
                labels.append(particle)

    return np.array(patches), np.array(labels)

patches, labels = extract_patches(tomogram_vals, picks, patch_size=16)

# Normalize patches
patches = patches / np.max(patches)

# Encode labels to integers
label_map = {name: idx for idx, name in enumerate(set(labels))}
encoded_labels = np.array([label_map[label] for label in labels])

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(patches, encoded_labels, test_size=0.2, random_state=42)

# Add a channel dimension for CNN
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Define a 3D CNN
model = Sequential([
    Conv3D(32, kernel_size=(3, 3, 3), activation='relu', input_shape=(16, 16, 16, 1)),
    MaxPooling3D(pool_size=(2, 2, 2)),
    Conv3D(64, kernel_size=(3, 3, 3), activation='relu'),
    MaxPooling3D(pool_size=(2, 2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(label_map), activation='softmax')  # Output layer for classification
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy:.2f}")

# Save the model
# model.save('particle_detection_model.h5')
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2128 - loss: 1.7651 - val_accuracy: 0.4286 - val_loss: 1.4845
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4043 - loss: 1.5129 - val_accuracy: 0.5714 - val_loss: 1.3438
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5192 - loss: 1.4204 - val_accuracy: 0.7143 - val_loss: 1.2446
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5952 - loss: 1.2679 - val_accuracy: 0.7500 - val_loss: 1.1034
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6056 - loss: 1.0668 - val_accuracy: 0.6429 - val_loss: 0.9634
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7336 - loss: 0.9246 - val_accuracy: 0.7143 - val_loss: 0.8205
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6446 - loss: 0.8959 - val_accuracy: 0.7500 - val_loss: 0.7375
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7216 - loss: 0.7580 - val_accuracy: 0.8214 - val_loss: 0.7042
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7420 - loss: 0.7010 - val_accuracy: 0.8214 - val_loss: 0.6514
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7627 - loss: 0.6261 - val_accuracy: 0.8214 - val_loss: 0.6089
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8179 - loss: 0.5674 - val_accuracy: 0.7857 - val_loss: 0.5855
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8840 - loss: 0.5142 - val_accuracy: 0.8214 - val_loss: 0.5425
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8356 - loss: 0.4966 - val_accuracy: 0.8214 - val_loss: 0.5364
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8200 - loss: 0.5651 - val_accuracy: 0.8214 - val_loss: 0.5248
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8423 - loss: 0.3915 - val_accuracy: 0.6786 - val_loss: 0.7144
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8403 - loss: 0.4662 - val_accuracy: 0.7500 - val_loss: 0.5746
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8590 - loss: 0.4261 - val_accuracy: 0.8214 - val_loss: 0.5445
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9074 - loss: 0.2813 - val_accuracy: 0.7500 - val_loss: 0.5590
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9048 - loss: 0.3062 - val_accuracy: 0.7500 - val_loss: 0.5647
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9256 - loss: 0.2684 - val_accuracy: 0.6786 - val_loss: 0.6109
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9381 - loss: 0.2369 - val_accuracy: 0.7857 - val_loss: 0.5596
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9615 - loss: 0.1794 - val_accuracy: 0.7500 - val_loss: 0.6376
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9110 - loss: 0.2094 - val_accuracy: 0.7500 - val_loss: 0.6262
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9620 - loss: 0.1415 - val_accuracy: 0.7857 - val_loss: 0.6522
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9672 - loss: 0.1491 - val_accuracy: 0.7500 - val_loss: 0.5806
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9584 - loss: 0.1472 - val_accuracy: 0.8214 - val_loss: 0.4836
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9823 - loss: 0.1014 - val_accuracy: 0.8571 - val_loss: 0.4751
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9464 - loss: 0.1488 - val_accuracy: 0.8214 - val_loss: 0.4957
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9709 - loss: 0.1053 - val_accuracy: 0.7500 - val_loss: 0.5857
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0676 - val_accuracy: 0.7500 - val_loss: 0.6725
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9485 - loss: 0.1306 - val_accuracy: 0.7857 - val_loss: 0.5520
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9703 - loss: 0.1067 - val_accuracy: 0.8214 - val_loss: 0.5003
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9943 - loss: 0.0688 - val_accuracy: 0.8929 - val_loss: 0.5073
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9875 - loss: 0.0566 - val_accuracy: 0.8214 - val_loss: 0.5266
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9677 - loss: 0.0814 - val_accuracy: 0.8214 - val_loss: 0.5294
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9641 - loss: 0.0869 - val_accuracy: 0.8214 - val_loss: 0.5418
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0383 - val_accuracy: 0.8214 - val_loss: 0.4926
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9813 - loss: 0.0748 - val_accuracy: 0.8214 - val_loss: 0.4712
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9927 - loss: 0.0392 - val_accuracy: 0.8214 - val_loss: 0.5638
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9823 - loss: 0.0755 - val_accuracy: 0.8214 - val_loss: 0.8156
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9662 - loss: 0.1137 - val_accuracy: 0.7143 - val_loss: 0.7454
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0576 - val_accuracy: 0.7500 - val_loss: 0.6748
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9943 - loss: 0.0290 - val_accuracy: 0.8214 - val_loss: 0.5546
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9912 - loss: 0.0368 - val_accuracy: 0.8571 - val_loss: 0.5740
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9818 - loss: 0.0521 - val_accuracy: 0.7143 - val_loss: 0.7858
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9792 - loss: 0.0521 - val_accuracy: 0.7143 - val_loss: 1.0690
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9610 - loss: 0.0890 - val_accuracy: 0.7500 - val_loss: 0.7081
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9912 - loss: 0.0505 - val_accuracy: 0.8214 - val_loss: 0.5563
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9906 - loss: 0.0423 - val_accuracy: 0.8214 - val_loss: 0.5586
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9547 - loss: 0.0963 - val_accuracy: 0.7500 - val_loss: 0.6686
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.7500 - val_loss: 0.8169
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9849 - loss: 0.0485 - val_accuracy: 0.7143 - val_loss: 0.7649
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.8214 - val_loss: 0.6007
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9912 - loss: 0.0156 - val_accuracy: 0.8571 - val_loss: 0.5723
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9912 - loss: 0.0387 - val_accuracy: 0.8214 - val_loss: 0.6169
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8214 - val_loss: 0.6443
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.8214 - val_loss: 0.6500
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8571 - val_loss: 0.6416
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.8571 - val_loss: 0.6635
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8571 - val_loss: 0.6860
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8571 - val_loss: 0.6917
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8214 - val_loss: 0.7222
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.8214 - val_loss: 0.6984
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9912 - loss: 0.0231 - val_accuracy: 0.8214 - val_loss: 0.6536
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8214 - val_loss: 0.6613
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.7857 - val_loss: 0.7073
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.7857 - val_loss: 0.7160
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.7857 - val_loss: 0.7069
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9943 - loss: 0.0152 - val_accuracy: 0.7857 - val_loss: 0.7119
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7857 - val_loss: 0.7362
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.7857 - val_loss: 0.7241
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8571 - val_loss: 0.6927
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9964 - loss: 0.0136 - val_accuracy: 0.8571 - val_loss: 0.7017
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.7857 - val_loss: 0.8181
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.7857 - val_loss: 0.8449
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9698 - loss: 0.0348 - val_accuracy: 0.7500 - val_loss: 0.7630
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9943 - loss: 0.0297 - val_accuracy: 0.7500 - val_loss: 0.9847
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.8214 - val_loss: 0.7328
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8571 - val_loss: 0.6096
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8214 - val_loss: 0.6189
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9912 - loss: 0.0183 - val_accuracy: 0.8214 - val_loss: 0.6352
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8214 - val_loss: 0.6759
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.7857 - val_loss: 0.7094
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.7857 - val_loss: 0.7053
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.7857 - val_loss: 0.6899
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8214 - val_loss: 0.6701
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8214 - val_loss: 0.6581
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8214 - val_loss: 0.6640
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8214 - val_loss: 0.6665
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8214 - val_loss: 0.6739
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8214 - val_loss: 0.6857
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9964 - loss: 0.0058 - val_accuracy: 0.8214 - val_loss: 0.6848
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8571 - val_loss: 0.6901
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8214 - val_loss: 0.7040
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.8571 - val_loss: 0.6657
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8214 - val_loss: 0.6573
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.7857 - val_loss: 0.7149
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7857 - val_loss: 0.7672
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.7500 - val_loss: 0.7796
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7857 - val_loss: 0.7728
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.7857 - val_loss: 0.7666
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7857 - val_loss: 0.7902
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.7857 - val_loss: 0.8103
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9849 - loss: 0.0344 - val_accuracy: 0.8214 - val_loss: 0.7725
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8929 - val_loss: 0.8003
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9964 - loss: 0.0147 - val_accuracy: 0.8571 - val_loss: 0.7930
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7857 - val_loss: 0.8661
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7500 - val_loss: 0.9024
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7500 - val_loss: 0.8916
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.7500 - val_loss: 0.8567
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9943 - loss: 0.0143 - val_accuracy: 0.8214 - val_loss: 0.6990
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8571 - val_loss: 0.6808
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8571 - val_loss: 0.6841
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.8571 - val_loss: 0.7520
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.7857 - val_loss: 0.8134
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.7500 - val_loss: 0.9304
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7500 - val_loss: 1.0863
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.7500 - val_loss: 0.9198
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.7857 - val_loss: 0.7989
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7857 - val_loss: 0.8042
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.7857 - val_loss: 0.6910
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8571 - val_loss: 0.6497
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9849 - loss: 0.0159 - val_accuracy: 0.8571 - val_loss: 0.6211
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8571 - val_loss: 0.6511
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9912 - loss: 0.0143 - val_accuracy: 0.8571 - val_loss: 0.6738
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8214 - val_loss: 0.7611
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.7857 - val_loss: 0.9176
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.7857 - val_loss: 0.9229
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8214 - val_loss: 0.8400
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7857 - val_loss: 0.7908
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7857 - val_loss: 0.7605
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 7.5224e-04 - val_accuracy: 0.7857 - val_loss: 0.7392
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8214 - val_loss: 0.7312
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8214 - val_loss: 0.7445
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8571 - val_loss: 0.7636
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8571 - val_loss: 0.7687
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 8.6594e-04 - val_accuracy: 0.8571 - val_loss: 0.7700
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8571 - val_loss: 0.7684
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8571 - val_loss: 0.7675
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8571 - val_loss: 0.7725
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.7857 - val_loss: 0.7367
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7857 - val_loss: 0.7176
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 6.3414e-04 - val_accuracy: 0.8214 - val_loss: 0.7097
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8214 - val_loss: 0.7024
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 4.2671e-04 - val_accuracy: 0.8214 - val_loss: 0.6889
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8214 - val_loss: 0.6890
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8214 - val_loss: 0.7008
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8214 - val_loss: 0.7186
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8214 - val_loss: 0.7312
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 4.0900e-04 - val_accuracy: 0.8214 - val_loss: 0.7430
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 3.9436e-04 - val_accuracy: 0.8214 - val_loss: 0.7527
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 6.5558e-04 - val_accuracy: 0.8214 - val_loss: 0.7608
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 7.6908e-04 - val_accuracy: 0.8214 - val_loss: 0.7716
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7857 - val_loss: 0.7770
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8214 - val_loss: 0.7961
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8214 - val_loss: 0.8364
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 2.6033e-04 - val_accuracy: 0.8214 - val_loss: 0.8900
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8214 - val_loss: 0.8912
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 9.1757e-04 - val_accuracy: 0.8214 - val_loss: 0.8784
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8214 - val_loss: 0.8926
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 6.0148e-04 - val_accuracy: 0.8214 - val_loss: 0.9073
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8214 - val_loss: 0.8949
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8214 - val_loss: 0.8849
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 4.3061e-04 - val_accuracy: 0.8214 - val_loss: 0.8843
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7857 - val_loss: 0.8513
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7857 - val_loss: 0.8514
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 5.1592e-04 - val_accuracy: 0.7857 - val_loss: 0.8549
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 8.2816e-04 - val_accuracy: 0.7857 - val_loss: 0.8580
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7857 - val_loss: 0.8585
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 2.8629e-04 - val_accuracy: 0.7857 - val_loss: 0.8624
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 1.9900e-04 - val_accuracy: 0.7857 - val_loss: 0.8665
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8214 - val_loss: 0.9521
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.7857 - val_loss: 1.0341
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7857 - val_loss: 1.0684
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 5.7154e-04 - val_accuracy: 0.7857 - val_loss: 1.0613
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 6.6299e-04 - val_accuracy: 0.7857 - val_loss: 1.0342
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 7.0901e-04 - val_accuracy: 0.7857 - val_loss: 1.0021
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8214 - val_loss: 0.9745
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8214 - val_loss: 0.9381
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7857 - val_loss: 0.9161
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 2.1124e-04 - val_accuracy: 0.7857 - val_loss: 0.9046
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 2.5022e-04 - val_accuracy: 0.7857 - val_loss: 0.9007
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.7857 - val_loss: 0.8912
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7857 - val_loss: 0.8758
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7857 - val_loss: 0.8773
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7857 - val_loss: 0.8950
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 3.7646e-04 - val_accuracy: 0.7857 - val_loss: 0.9224
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8214 - val_loss: 0.9468
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 1.7456e-04 - val_accuracy: 0.8214 - val_loss: 0.9659
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 6.6145e-04 - val_accuracy: 0.8214 - val_loss: 0.9766
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 2.7001e-04 - val_accuracy: 0.8214 - val_loss: 0.9729
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 3.0754e-04 - val_accuracy: 0.8214 - val_loss: 0.9634
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8214 - val_loss: 1.0012
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 9.1824e-04 - val_accuracy: 0.7857 - val_loss: 1.1137
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7857 - val_loss: 1.1960
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 9.7764e-04 - val_accuracy: 0.8214 - val_loss: 1.2578
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 1.5611e-04 - val_accuracy: 0.8214 - val_loss: 1.2950
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 2.6723e-04 - val_accuracy: 0.8214 - val_loss: 1.3134
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 8.4208e-04 - val_accuracy: 0.8214 - val_loss: 1.2747
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7857 - val_loss: 1.1462
# Test Accuracy: 0.79
