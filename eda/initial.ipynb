# %%
import zarr
from matplotlib import pyplot as plt

# %%
zarr_path = '../Data/czii-cryo-et-object-identification/train/static/ExperimentRuns/TS_5_4/VoxelSpacing10.000/denoised.zarr'

# %%
zarr_file = zarr.open(zarr_path, mode='r')
zarr_file.tree()
# Out:
# Tree(nodes=(Node(disabled=True, name='/', nodes=(Node(disabled=True, icon='table', name='0 (184, 630, 630) flo…

# %%
data = zarr_file['0']

# %%
print(data.shape)
print(data.dtype)
# Out:
# (184, 630, 630)
# float32

# %%
plt.imshow(data[90,:,:],cmap='gray')
plt.show()
